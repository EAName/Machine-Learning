# %%
import numpy as np
import matplotlib.pyplot as plt
import os
#with OS package, use /Users/username instead of ~ for the home directory
#pip install opencv-python
import cv2

import random
import collections
import pickle

# %%
PATH = '/Users/edwin/Desktop/Edwin/Academic/Summer2022/MSDS434/Project/archive/images'

TRAIN_PATH = PATH + '/images'
#TEST_PATH = PATH + '/test'

CATEGORIES = ['AIRPLANES & RUNWAYS']

#print(os.getcwd())

# %%
def getImages( WHERE, IMG_SIZE ) :
    imgList = []
    for category in CATEGORIES :
        target_num = CATEGORIES.index( category )
        path = os.path.join( WHERE, category )
        print( "path=", path)
        for img in os.listdir( path ) :
            try:
                filename = os.path.join( path, img )
                img_array = cv2.imread( filename, cv2.IMREAD_GRAYSCALE )
                print( "BEFORE .... ", img_array.shape )
                new_array = cv2.resize( img_array, (IMG_SIZE, IMG_SIZE) )
                print( "AFTER .... ", new_array.shape )
                imgList.append( [new_array, target_num])
            except Exception as e:
                pass
    return imgList

# %%
# SET THIS TO WHATEVER SIZE YOU THINK IS BEST ....
IMG_SIZE = 1000

# trainData = getImages( TEST_PATH, IMG_SIZE  )
# testData = getImages( TEST_PATH, IMG_SIZE  )

#totalData = getImages( TRAIN_PATH, IMG_SIZE  ) + getImages( TEST_PATH, IMG_SIZE  )
totalData = getImages( PATH, IMG_SIZE  )
# Out:
# path= /Users/edwin/Desktop/Edwin/Academic/Summer2022/MSDS434/Project/archive/images/AIRPLANES & RUNWAYS
# BEFORE ....  (2560, 2560)
# AFTER ....  (1000, 1000)
# BEFORE ....  (2560, 2560)
# AFTER ....  (1000, 1000)
# BEFORE ....  (2560, 2560)
# AFTER ....  (1000, 1000)
# BEFORE ....  (2560, 2560)
# AFTER ....  (1000, 1000)
# BEFORE ....  (2560, 2560)
# AFTER ....  (1000, 1000)
# BEFORE ....  (2560, 2560)
# AFTER ....  (1000, 1000)
# BEFORE ....  (2560, 2560)
# AFTER ....  (1000, 1000)
# BEFORE ....  (2560, 2560)
# AFTER ....  (1000, 1000)
# BEFORE ....  (2560, 2560)
# AFTER ....  (1000, 1000)
# BEFORE ....  (2560, 2560)
# AFTER ....  (1000, 1000)
# BEFORE ....  (2560, 2560)
# AFTER ....  (1000, 1000)
# BEFORE ....  (2560, 2560)
# AFTER ....  (1000, 1000)
# BEFORE ....  (2560, 2560)
# AFTER ....  (1000, 1000)
# BEFORE ....  (2560, 2560)
# AFTER ....  (1000, 1000)
# BEFORE ....  (2560, 2560)
# AFTER ....  (1000, 1000)
# BEFORE ....  (2560, 2560)
# AFTER ....  (1000, 1000)
# BEFORE ....  (2560, 2560)
# AFTER ....  (1000, 1000)
# BEFORE ....  (2560, 2560)
# AFTER ....  (1000, 1000)
# BEFORE ....  (2560, 2560)
# AFTER ....  (1000, 1000)
# BEFORE ....  (2560, 2560)
# AFTER ....  (1000, 1000)
# BEFORE ....  (2560, 2560)
# AFTER ....  (1000, 1000)
# BEFORE ....  (2560, 2560)
# AFTER ....  (1000, 1000)
# BEFORE ....  (2560, 2560)
# AFTER ....  (1000, 1000)
# BEFORE ....  (2560, 2560)
# AFTER ....  (1000, 1000)
# BEFORE ....  (2560, 2560)
# AFTER ....  (1000, 1000)
# BEFORE ....  (2560, 2560)
# AFTER ....  (1000, 1000)
# BEFORE ....  (2560, 2560)
# AFTER ....  (1000, 1000)
# BEFORE ....  (2560, 2560)
# AFTER ....  (1000, 1000)
# BEFORE ....  (2560, 2560)
# AFTER ....  (1000, 1000)
# BEFORE ....  (2560, 2560)
# AFTER ....  (1000, 1000)
# BEFORE ....  (2560, 2560)
# AFTER ....  (1000, 1000)
# BEFORE ....  (2560, 2560)
# AFTER ....  (1000, 1000)
# BEFORE ....  (2560, 2560)
# AFTER ....  (1000, 1000)
# BEFORE ....  (2560, 2560)
# AFTER ....  (1000, 1000)
# BEFORE ....  (2560, 2560)
# AFTER ....  (1000, 1000)
# BEFORE ....  (2560, 2560)
# AFTER ....  (1000, 1000)
# BEFORE ....  (2560, 2560)
# AFTER ....  (1000, 1000)
# BEFORE ....  (2560, 2560)
# AFTER ....  (1000, 1000)
# BEFORE ....  (2560, 2560)
# AFTER ....  (1000, 1000)
# BEFORE ....  (2560, 2560)
# AFTER ....  (1000, 1000)
# BEFORE ....  (2560, 2560)
# AFTER ....  (1000, 1000)
# BEFORE ....  (2560, 2560)
# AFTER ....  (1000, 1000)
# BEFORE ....  (2560, 2560)
# AFTER ....  (1000, 1000)
# BEFORE ....  (2560, 2560)
# AFTER ....  (1000, 1000)
# BEFORE ....  (2560, 2560)
# AFTER ....  (1000, 1000)
# BEFORE ....  (2560, 2560)
# AFTER ....  (1000, 1000)
# BEFORE ....  (2560, 2560)
# AFTER ....  (1000, 1000)
# BEFORE ....  (2560, 2560)
# AFTER ....  (1000, 1000)
# BEFORE ....  (2560, 2560)
# AFTER ....  (1000, 1000)
# BEFORE ....  (2560, 2560)
# AFTER ....  (1000, 1000)
# BEFORE ....  (2560, 2560)
# AFTER ....  (1000, 1000)
# BEFORE ....  (2560, 2560)
# AFTER ....  (1000, 1000)
# BEFORE ....  (2560, 2560)
# AFTER ....  (1000, 1000)
# BEFORE ....  (2560, 2560)
# AFTER ....  (1000, 1000)
# BEFORE ....  (2560, 2560)
# AFTER ....  (1000, 1000)
# BEFORE ....  (2560, 2560)
# AFTER ....  (1000, 1000)
# BEFORE ....  (2560, 2560)
# AFTER ....  (1000, 1000)
# BEFORE ....  (2560, 2560)
# AFTER ....  (1000, 1000)
# BEFORE ....  (2560, 2560)
# AFTER ....  (1000, 1000)
# BEFORE ....  (2560, 2560)
# AFTER ....  (1000, 1000)
# BEFORE ....  (2560, 2560)
# AFTER ....  (1000, 1000)
# BEFORE ....  (2560, 2560)
# AFTER ....  (1000, 1000)
# BEFORE ....  (2560, 2560)
# AFTER ....  (1000, 1000)
# BEFORE ....  (2560, 2560)
# AFTER ....  (1000, 1000)
# BEFORE ....  (2560, 2560)
# AFTER ....  (1000, 1000)
# BEFORE ....  (2560, 2560)
# AFTER ....  (1000, 1000)
# BEFORE ....  (2560, 2560)
# AFTER ....  (1000, 1000)
# BEFORE ....  (2560, 2560)
# AFTER ....  (1000, 1000)
# BEFORE ....  (2560, 2560)
# AFTER ....  (1000, 1000)
# BEFORE ....  (2560, 2560)
# AFTER ....  (1000, 1000)
# BEFORE ....  (2560, 2560)
# AFTER ....  (1000, 1000)
# BEFORE ....  (2560, 2560)
# AFTER ....  (1000, 1000)
# BEFORE ....  (2560, 2560)
# AFTER ....  (1000, 1000)
# BEFORE ....  (2560, 2560)
# AFTER ....  (1000, 1000)
# BEFORE ....  (2560, 2560)
# AFTER ....  (1000, 1000)
# BEFORE ....  (2560, 2560)
# AFTER ....  (1000, 1000)
# BEFORE ....  (2560, 2560)
# AFTER ....  (1000, 1000)
# BEFORE ....  (2560, 2560)
# AFTER ....  (1000, 1000)
# BEFORE ....  (2560, 2560)
# AFTER ....  (1000, 1000)
# BEFORE ....  (2560, 2560)
# AFTER ....  (1000, 1000)
# BEFORE ....  (2560, 2560)
# AFTER ....  (1000, 1000)
# BEFORE ....  (2560, 2560)
# AFTER ....  (1000, 1000)
# BEFORE ....  (2560, 2560)
# AFTER ....  (1000, 1000)
# BEFORE ....  (2560, 2560)
# AFTER ....  (1000, 1000)
# BEFORE ....  (2560, 2560)
# AFTER ....  (1000, 1000)
# BEFORE ....  (2560, 2560)
# AFTER ....  (1000, 1000)
# BEFORE ....  (2560, 2560)
# AFTER ....  (1000, 1000)
# BEFORE ....  (2560, 2560)
# AFTER ....  (1000, 1000)
# BEFORE ....  (2560, 2560)
# AFTER ....  (1000, 1000)
# BEFORE ....  (2560, 2560)
# AFTER ....  (1000, 1000)
# BEFORE ....  (2560, 2560)
# AFTER ....  (1000, 1000)
# BEFORE ....  (2560, 2560)
# AFTER ....  (1000, 1000)
# BEFORE ....  (2560, 2560)
# AFTER ....  (1000, 1000)
# BEFORE ....  (2560, 2560)
# AFTER ....  (1000, 1000)
# BEFORE ....  (2560, 2560)
# AFTER ....  (1000, 1000)
# BEFORE ....  (2560, 2560)
# AFTER ....  (1000, 1000)
# BEFORE ....  (2560, 2560)
# AFTER ....  (1000, 1000)
# BEFORE ....  (2560, 2560)
# AFTER ....  (1000, 1000)
# BEFORE ....  (2560, 2560)
# AFTER ....  (1000, 1000)
# BEFORE ....  (2560, 2560)
# AFTER ....  (1000, 1000)
# BEFORE ....  (2560, 2560)
# AFTER ....  (1000, 1000)
# BEFORE ....  (2560, 2560)
# AFTER ....  (1000, 1000)
# BEFORE ....  (2560, 2560)
# AFTER ....  (1000, 1000)

# %%
who = 0

print( "Total Images",len( totalData ))
countList = [i[1] for i in totalData ]
ctr = collections.Counter( countList )
for i in CATEGORIES :
    print("Category",i,"=",ctr[ CATEGORIES.index(i)] )

random.shuffle( totalData )
theRecord = totalData[who]
theValue = theRecord[1]
theImg = theRecord[0]
plt.imshow( theImg, cmap="gray" )
plt.show()

print("This is an image of",CATEGORIES[ theValue ] )
# Out:
# Total Images 103
# Category AIRPLANES & RUNWAYS = 103
# This is an image of AIRPLANES & RUNWAYS

# %%
# 10 x 10 grid, each pixel has a single value associated with it
X = []
Y = []

for [features,label] in totalData :
    X.append( features )
    Y.append( label )
#for a color image you would use (-1, IMG_SIZE, IMG_SIZE, 3) the last position is the number of channels
# the negative is useful to interpret the correct number of images and input it in where the negative one is
X = np.array( X ).reshape( -1, IMG_SIZE, IMG_SIZE, 1)
print( X.shape )

Y = np.array( Y ).reshape( -1, )
print( Y.shape )
# Out:
# (103, 1000, 1000, 1)
# (103,)

# %%
pickle_out = open("X.pickle","wb")
pickle.dump( X, pickle_out )
pickle_out.close()

pickle_out = open("Y.pickle","wb")
pickle.dump( Y, pickle_out )
pickle_out.close()

# %%
print(X[0])
# Out:
# [[[151]
#   [145]
#   [152]
#   ...
#   [177]
#   [190]
#   [191]]
#
#  [[141]
#   [162]
#   [156]
#   ...
#   [191]
#   [192]
#   [178]]
#
#  [[ 94]
#   [129]
#   [175]
#   ...
#   [197]
#   [197]
#   [192]]
#
#  ...
#
#  [[ 78]
#   [ 72]
#   [ 79]
#   ...
#   [ 60]
#   [ 68]
#   [ 58]]
#
#  [[111]
#   [ 88]
#   [ 71]
#   ...
#   [ 58]
#   [ 68]
#   [ 66]]
#
#  [[ 81]
#   [107]
#   [103]
#   ...
#   [ 63]
#   [ 66]
#   [ 69]]]
