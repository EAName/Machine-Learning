# %%
import matplotlib.pyplot as plt
import numpy as np

import cv2
import os

import pickle
import tensorflow as tf

# %%
model = tf.keras.models.load_model( "TFNN.pet.model" )
# Out:
# 2022-08-27 16:35:46.448654: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
CATEGORIES = ["CAT","DOG"]
IMG_SIZE = 80

PATH = '/Users/edwin/Desktop/Edwin/Academic/Summer2022/MSDS422/Programming/QA/catdog'

# TRAIN_PATH = PATH + '/train'
# TEST_PATH = PATH + '/test'

IMGFILE = "DOG_001.jpg"
IMGFILE = "CAT_001.jpg"
IMGFILE = "DOG_002.jpg"
IMGFILE = "CAT_002.jpg"

#print(os.getcwd())

# %%
FILENAME = os.path.join( PATH, IMGFILE )
print( FILENAME )
IMG_RAW = cv2.imread( FILENAME, cv2.IMREAD_GRAYSCALE )
IMG = cv2.resize( IMG_RAW, (IMG_SIZE, IMG_SIZE) )

X_RAW = np.array( IMG ).reshape( -1, IMG_SIZE, IMG_SIZE, 1)
# Out:
# /Users/edwin/Desktop/Edwin/Academic/Summer2022/MSDS422/Programming/QA/catdog/CAT_002.jpg

# %%
plt.imshow( IMG_RAW, cmap="gray" )
plt.show()

# %%
plt.imshow( IMG, cmap="gray" )
plt.show()

# %%
# Normalize the Data

print( X_RAW.shape )
print( X_RAW.shape[1:] )

X = X_RAW/255.0
# Out:
# (1, 80, 80, 1)
# (80, 80, 1)

# %%
Y = np.argmax(model.predict(X), axis=-1)
Y = Y[0]
print(Y)
print("This is a .....", CATEGORIES[Y])
# Out:
# 0
# This is a ..... CAT
